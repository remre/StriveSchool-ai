# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as sch
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('CC_GENERAL.csv')

# %%
df.sample(n=50)

# %%
df.isna().sum()

# %%
df['MINIMUM_PAYMENTS'].fillna((df['MINIMUM_PAYMENTS'].mean()), inplace=True)

# %%
df['CREDIT_LIMIT'].fillna((df['CREDIT_LIMIT'].mean()), inplace=True)

# %%
df.head()

# %%
points = df.iloc[:,1:]
points

# %%
df.isnull().sum()

# %%
corr = df.corr()
plt.figure(figsize=(15, 15))
matrix = np.triu(df.corr())
sns.heatmap(corr,annot=True,fmt=".2",cmap= 'coolwarm',linewidths=2,square = True)

# %%
num_vars = ["",""]

# %%
for i in num_vars:
    plt.figure(figsize=(16,1))
    sns.boxplot(x=df[i])

# %%
model = KMeans(n_clusters = 2)
labels = model.fit_predict(points)
labels
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int32)

# %%
import plotly.express as px
fig = px.scatter_matrix(df.drop("CUST_ID",axis=1),
width=2000, height=3000)
fig.show()

# %%
import seaborn as sns
plt.figure(figsize=(6, 6))
sns.scatterplot(x=data_0[:, 0], y=data_0[:, 1], label='0')
sns.scatterplot(x=data_1[:, 0], y=data_1[:, 1], label='1')
sns.scatterplot(x=data_2[:, 0], y=data_2[:, 1], label='2')

# %%
def separate_new_labels(labels, points):

    # YOUR CODE HERE
    for index ,i in enumerate (labels):
        if i==0:
            new_0.append(points[index])
        elif i==1:
            new_1.append(points[index])
        elif i==2:
            new_2.append(points[index])
            
    return np.array(new_0), np.array(new_1), np.array(new_2)

# %%
for i in range(2,11):
  kmeans = KMeans(n_clusters=i, random_state=42)
  print("Number of Clusters : " + str(i))
  evaluate(kmeans, pcadf)
  print("====================")

# %%
import scipy.cluster.hierarchy as sch

# %%
mergins = sch.linkage(points, 'complete')
dn = sch.dendrogram(mergins, leaf_rotation = 90, leaf_font_size=6)

# %%
f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,8))
ax1.set_title('K Means')
ax1.scatter(points[:,0],vals[:,1],c=labels,cmap='autumn')
ax2.set_title("Original")
ax2.scatter(points[:,0],points[:,1])
ax1.grid()
ax2.grid()

# %%
from sklearn.preprocessing import MinMaxScaler
import plotly.graph_objects as go
X=df.drop("CUST_ID",axis=1)

scaler = MinMaxScaler()
scaler.fit(points)
X=scaler.transform(points)
inertia = []
for i in range(1,11):
    kmeans = KMeans(
        n_clusters=i, init="k-means++",
        n_init=10,
        tol=1e-04, random_state=0
    )
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
fig = go.Figure(data=go.Scatter(x=np.arange(1,11),y=inertia))
fig.update_layout(title="Inertia vs Cluster Number",xaxis=dict(range=[0,11],title="Cluster Number"),
                  yaxis={'title':'Inertia'},
                 annotations=[
        dict(
            x=2,
            y=inertia[1],
            xref="x",
            yref="y",
            text="Elbow!",
            showarrow=True,
            arrowhead=7,
            ax=20,
            ay=-40
        )
    ])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9546e013-2044-4101-92cf-0a65900997f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9546e013-2044-4101-92cf-0a65900997f8")) {
#                     Plotly.newPlot(
#                         '9546e013-2044-4101-92cf-0a65900997f8',
# ...

# %%
clusters['label']=kmeans.labels_
polar=clusters.groupby("label").mean().reset_index()
polar=pd.melt(polar,id_vars=["label"])
fig4 = px.line_polar(polar, r="value", theta="variable", color="label", line_close=True,height=800,width=1400)
fig.show()

# %%
for i in range(2,11):
  kmeans = KMeans(n_clusters=i, random_state=42)
  print("Number of Clusters : " + str(i))
  evaluate(kmeans, pcadf)
  print("====================")
# Out:
# Number of Clusters : 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-a9ac16b518dd> in <module>()
#       2   kmeans = KMeans(n_clusters=i, random_state=42)
#       3   print("Number of Clusters : " + str(i))
# ----> 4   evaluate(kmeans, pcadf)
#       5   print("====================")
#
# NameError: name 'evaluate' is not defined
