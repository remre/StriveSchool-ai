# %% [markdown]
# <a href="https://colab.research.google.com/github/remre/StriveSchool-ai/blob/main/bw1/youtoubetranscribeapi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-15f68172b8b3> in <module>()
# ----> 1 from youtube_transcript_api import YouTubeTranscriptApi
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# retrieve the available transcripts
transcript_list = YouTubeTranscriptApi.list_transcripts("spUNpyF58BY&ab")

# iterate over all available transcripts
for transcript in transcript_list:


    # fetch the actual transcript data

    # translating the transcript will return another transcript object
    print(transcript.translate('en').fetch())

# you can also directly filter for the language you are looking for, using the transcript list
transcript = transcript_list.find_transcript(['de', 'en'])  

# or just filter for manually created transcripts  
transcript = transcript_list.find_manually_created_transcript(['de', 'en'])  

# or automatically generated ones  
transcript = transcript_list.find_generated_transcript(['de', 'en'])
# Out:
# [{'text': 'What you see here is what we are going to build in this video', 'start': 4.34, 'duration': 2.939}, {'text': 'An experiment to think about a very important idea in mathematics', 'start': 7.28, 'duration': 4.32}, {'text': 'Fourer transform', 'start': 11.6, 'duration': 1.359}, {'text': "for those unfamiliar with what I'm doing", 'start': 13.26, 'duration': 2.38}, {'text': 'My first goal here is for the video to be an introduction to this topic', 'start': 15.64, 'duration': 4.54}, {'text': 'but even for those of you who are familiar with the topic', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think there is something interesting', 'start': 22.86, 'duration': 1.64}, {'text': "And it's useful to see what its elements really look like. The", 'start': 24.5, 'duration': 4.3}, {'text': "example from which we're going to start is the classic example of", 'start': 29.24, 'duration': 3.08}, {'text': 'decoding frequencies from sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'But then I also want to offer a glimpse of how this idea extends far beyond sound and frequencies and', 'start': 34.36, 'duration': 6.36}, {'text': 'gets into a lot of physical and mathematical situations that might seem really far from it.', 'start': 40.72, 'duration': 3.7}, {'text': '\n', 'start': 50.54, 'duration': 2.16}, {'text': 'At a frequency of 440 vibrations per second,', 'start': 53.02, 'duration': 1.96}, {'text': 'this means that if you measure the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'right next to your audio speakers or next to the loudspeaker as a function of time, the pressure will fluctuate up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around the value of the usual equilibrium pressure, forming this wave at', 'start': 63.16, 'duration': 2.94}, {'text': '440 vibrations per second A', 'start': 66.1, 'duration': 3.4}, {'text': 'lower pitch sound like\nD\nwill be of the same structure  , but with fewer vibrations every second and', 'start': 69.5, 'duration': 5.52}, {'text': 'when you play both of them, what do you think the pressure graph will look like as a function of time?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any given moment this pressure change is', 'start': 82.16, 'duration': 3.019}, {'text': 'going to be the sum of their individual sound and', 'start': 85.18, 'duration': 4.1}, {'text': "it's - let's face it - kind of complicated at some", 'start': 89.28, 'duration': 3.68}, {'text': 'points the peaks fit together', 'start': 94.08, 'duration': 2.24}, {'text': 'producing very high pressure and', 'start': 96.32, 'duration': 2.099}, {'text': 'at other points they just vanish', 'start': 98.42, 'duration': 2.32}, {'text': 'and overall what you get is a wave-like shape  The shape of the pressure is graphed as a function of time, and', 'start': 101.38, 'duration': 4.0}, {'text': "it's not a pure sinusoidal function. It's a bit more complicated. As you", 'start': 105.38, 'duration': 3.62}, {'text': 'add more sounds, the wave gets more complex,', 'start': 109.0, 'duration': 4.52}, {'text': "but now all it's made of is a set of pure frequencies,", 'start': 113.68, 'duration': 4.4}, {'text': 'so the output seems to be more complicated than necessary when we know the small amount of information it contains', 'start': 118.08, 'duration': 4.32}, {'text': 'when a microphone records  Any sound,', 'start': 122.96, 'duration': 2.019}, {'text': 'it records the value of the air pressure at many different values of time,', 'start': 124.98, 'duration': 3.18}, {'text': 'only seeing the final product of the sum.', 'start': 128.419, 'duration': 2.06}, {'text': 'Our central question, then, will be: How do you take', 'start': 130.479, 'duration': 2.92}, {'text': 'a signal like this and', 'start': 133.4, 'duration': 1.38}, {'text': 'break it down', 'start': 134.78, 'duration': 1.1}, {'text': 'into its constituent pure frequencies?', 'start': 135.88, 'duration': 2.12}, {'text': "Interesting, isn't it?", 's ...
# [{'text': 'The above shows are what we are discussing in this video.', 'start': 4.34, 'duration': 2.94}, {'text': 'Thinking about a super important concept in mathematics in an animated way.\nFourier transform.', 'start': 7.28, 'duration': 4.32}, {'text': 'For those who are unfamiliar,', 'start': 13.26, 'duration': 2.38}, {'text': 'my primary goal is to introduce "Fourier', 'start': 15.64, 'duration': 4.54}, {'text': 'But even if you are already familiar with the concept of "Ye Transformation",', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think you can get a more interesting and in-depth understanding here.', 'start': 22.86, 'duration': 5.74}, {'text': 'First, let’s take a very classic example', 'start': 29.24, 'duration': 3.08}, {'text': 'of decomposing frequency from sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'But after that, I want to explain that the scope of application of this idea is far more than sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'in many seemingly unrelated fields of mathematics, and even in the physical world.  Can be used.', 'start': 40.72, 'duration': 3.7}, {'text': 'Really, this idea is everywhere and exciting.', 'start': 44.6, 'duration': 3.52}, {'text': "Let's get to the topic.", 'start': 49.12, 'duration': 0.82}, {'text': 'Now we are playing pure A sound,', 'start': 50.54, 'duration': 2.16}, {'text': '440 beats per second.\nThis means that if you want to measure the air pressure around the earphone or sounder', 'start': 53.02, 'duration': 1.96}, {'text': 'as a function of time, then this function will also oscillate up and down near its equilibrium point and', 'start': 57.5, 'duration': 8.6}, {'text': 'produce 440 oscillations per second.', 'start': 66.1, 'duration': 3.4}, {'text': 'For a bass note, such as D, it has the same structure, but the number of beats per second is reduced.', 'start': 69.5, 'duration': 5.52}, {'text': 'When these two sounds are played at the same time, what do you think is the final relationship between pressure and time?', 'start': 75.5, 'duration': 5.52}, {'text': 'So, at any moment, the change in this pressure difference is the', 'start': 82.16, 'duration': 3.02}, {'text': 'sum of the pressure generated by each tone.', 'start': 85.18, 'duration': 4.1}, {'text': 'Well, this thing is actually a bit complicated, and it’s hard to imagine that', 'start': 89.28, 'duration': 3.68}, {'text': 'at some point, the two peaks will overlap each other to', 'start': 94.08, 'duration': 2.24}, {'text': 'produce a higher air pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other moments, they will cancel each other out.', 'start': 98.42, 'duration': 2.32}, {'text': 'All in all, what you get is a wave-shaped graph of pressure versus time,', 'start': 101.38, 'duration': 4.0}, {'text': 'which is not a pure sine wave, but something more complicated.', 'start': 105.38, 'duration': 3.62}, {'text': 'As you add more tones, the waves will become more and more complicated.', 'start': 109.0, 'duration': 4.52}, {'text': 'But for now, it is a combination of four pure tones.\nSo it seems... this waveform has very little information, but it looks quite complicated.', 'start': 113.68, 'duration': 4.4}, {'text': 'When the microphone records any sound, it', 'start': 122.96, 'duration': 2.02}, {'text': 'only obtains the air pressure at different points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'It only "sees" the final sum of air pressure.', 'start': 128.419, 'duration': 2.06}, {'text': 'So our core question is', 'start': 130.479, 'duration': 2.921}, {'text': ': How to decompose such a signal and', 'start': 133.4, 'duration': 1.38}, {'text': 'find the frequency of the pure tone in it?', 'start': 135.88, 'duration': 2.12}, {'text': 'Sounds interesting, right?', 'start': 138.62, 'duration': 1.38}, {'text': 'Add these signals together and they are all mixed together.', 'start': 140.14, 'duration': 2.78}, {'text': 'So separating them... it feels li ...
# [{'text': 'The above shows are what we are discussing in this video.', 'start': 4.34, 'duration': 2.94}, {'text': 'Thinking about a super important concept in mathematics in an animated way.', 'start': 7.28, 'duration': 4.32}, {'text': 'Fourier transform.', 'start': 11.6, 'duration': 1.36}, {'text': 'For those who are unfamiliar,', 'start': 13.26, 'duration': 2.38}, {'text': 'my primary goal is to introduce "Fourier', 'start': 15.64, 'duration': 4.54}, {'text': 'But even if you are already familiar with the concept of "Ye Transformation",', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think you can get a more interesting and in-depth understanding here.', 'start': 22.86, 'duration': 5.74}, {'text': 'First, let’s take a very classic example', 'start': 29.24, 'duration': 3.08}, {'text': 'of decomposing frequency from sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'But after that, I want to explain that the scope of application of this idea is far more than sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'in many seemingly unrelated fields of mathematics, and even in the physical world.  Can be used.', 'start': 40.72, 'duration': 3.7}, {'text': 'Really, this idea is everywhere and exciting.', 'start': 44.6, 'duration': 3.52}, {'text': "Let's get to the topic.", 'start': 49.12, 'duration': 0.82}, {'text': 'Now we are playing pure A sound,', 'start': 50.54, 'duration': 2.16}, {'text': '440 beats per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'This means that if you want to measure the air pressure around the earphone or sounder', 'start': 54.98, 'duration': 2.52}, {'text': 'as a function of time, then this function will also oscillate up and down near its equilibrium point and', 'start': 57.5, 'duration': 8.6}, {'text': 'produce 440 oscillations per second.', 'start': 66.1, 'duration': 3.4}, {'text': 'For a bass note, such as D, it has the same structure, but the number of beats per second is reduced.', 'start': 69.5, 'duration': 5.52}, {'text': 'When these two sounds are played at the same time, what do you think is the final relationship between pressure and time?', 'start': 75.5, 'duration': 5.52}, {'text': 'So, at any moment, the change in this pressure difference is the', 'start': 82.16, 'duration': 3.02}, {'text': 'sum of the pressure generated by each tone.', 'start': 85.18, 'duration': 4.1}, {'text': 'Well, this thing is actually a bit complicated, and it’s hard to imagine that', 'start': 89.28, 'duration': 3.68}, {'text': 'at some point, the two peaks will overlap each other to', 'start': 94.08, 'duration': 2.24}, {'text': 'produce a higher air pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other moments, they will cancel each other out.', 'start': 98.42, 'duration': 2.32}, {'text': 'All in all, what you get is a wave-shaped graph of pressure versus time,', 'start': 101.38, 'duration': 4.0}, {'text': 'which is not a pure sine wave, but something more complicated.', 'start': 105.38, 'duration': 3.62}, {'text': 'As you add more tones, the waves will become more and more complicated.', 'start': 109.0, 'duration': 4.52}, {'text': 'But for now, it is a combination of four pure tones.', 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems... this waveform has very little information, but it looks quite complicated.', 'start': 118.08, 'duration': 4.32}, {'text': 'When the microphone records any sound, it', 'start': 122.96, 'duration': 2.02}, {'text': 'only obtains the air pressure at different points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'It only "sees" the final sum of air pressure.', 'start': 128.42, 'duration': 2.06}, {'text': 'So our core question is', 'start': 130.48, 'duration': 2.92}, {'text': ': How to decompose such a signal and', 'start': 133.4, 'duration': 1.38}, {'text': 'find the frequency of the pure tone in it?', 'start': 135.88, 'duration': 2.12}, {'text': 'Sounds interesting, right?', 'start': 138.62, 'duration': 1.38}, {'text': 'Add th ...
# [{'text': "This right here is what we're going to build to, this video:", 'start': 4.34, 'duration': 2.94}, {'text': 'A certain animated approach to thinking about a super-important idea from math:', 'start': 7.28, 'duration': 4.32}, {'text': 'The Fourier transform.', 'start': 11.6, 'duration': 1.36}, {'text': 'For anyone unfamiliar with what that is,', 'start': 13.26, 'duration': 2.38}, {'text': 'my #1 goal here is just for the video to be an introduction to that topic.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who are already familiar with it,', 'start': 20.18, 'duration': 2.68}, {'text': "I still think that there's something fun", 'start': 22.86, 'duration': 1.64}, {'text': 'and enriching about seeing what all of its components actually look like.', 'start': 24.5, 'duration': 4.3}, {'text': 'The central example, to start, is gonna be the classic one:', 'start': 29.24, 'duration': 3.08}, {'text': 'Decomposing frequencies from sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'But after that, I also really wanna show a glimpse of how this idea extends well beyond sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'and to many seemingly disparate areas of math, and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': 'Really, it is crazy just how ubiquitous this idea is.', 'start': 44.6, 'duration': 3.52}, {'text': "Let's dive in.", 'start': 49.12, 'duration': 0.82}, {'text': 'This sound right here is a pure A.', 'start': 50.54, 'duration': 2.16}, {'text': '440 beats per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'Meaning, if you were to measure the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'right next to your headphones, or your speaker, as a function of time, it would oscillate up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around its usual equilibrium, in this wave.', 'start': 63.16, 'duration': 2.94}, {'text': 'making 440 oscillations each second.', 'start': 66.1, 'duration': 3.4}, {'text': 'A lower-pitched note, like a D, has the same structure, just fewer beats per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when both of them are played at once, what do you think the resulting pressure vs. time graph looks like?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any point in time, this pressure difference', 'start': 82.16, 'duration': 3.02}, {'text': 'is gonna be the sum of what it would be for each of those notes individually.', 'start': 85.18, 'duration': 4.1}, {'text': "Which, let's face it, is kind of a complicated thing to think about.", 'start': 89.28, 'duration': 3.68}, {'text': 'At some points, the peaks match up with each other,', 'start': 94.08, 'duration': 2.24}, {'text': 'resulting in a really high pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other points, they tend to cancel out.', 'start': 98.42, 'duration': 2.32}, {'text': 'And all in all, what you get is a wave-ish pressure vs. time graph,', 'start': 101.38, 'duration': 4.0}, {'text': "that is not a pure sine wave; it's something more complicated.", 'start': 105.38, 'duration': 3.62}, {'text': 'And as you add in other notes, the wave gets more and more complicated.', 'start': 109.0, 'duration': 4.52}, {'text': 'But right now, all it is is a combination of four pure frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems...needlessly complicated, given the low amount of information put into it.', 'start': 118.08, 'duration': 4.32}, {'text': 'A microphone recording any sound', 'start': 122.96, 'duration': 2.02}, {'text': 'just picks up on the air pressure at many different points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'It only "sees" the final sum.', 'start': 128.42, 'duration': 2.06}, {'text': 'So our central question is gonna be how you can take', 'start': 130.48, 'duration': 2.92}, {'text': 'a signal like this,', 'start': 133.4, 'duration': 1.38}, {'text': 'and decompose it', 'start': 134.78, 'dur ...
# [{'text': "What you see there is what we'll build in this video:", 'start': 4.34, 'duration': 2.94}, {'text': 'A certain animated approach to thinking about a super-important idea in math:', 'start': 7.28, 'duration': 4.32}, {'text': 'The Fourier transform.', 'start': 11.6, 'duration': 1.36}, {'text': "For those who don't know what this is,", 'start': 13.26, 'duration': 2.38}, {'text': 'my # 1 goal here is just to make this video an introduction to it.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who already know it,', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think there is something fun', 'start': 22.86, 'duration': 1.64}, {'text': 'and rewarding about seeing what all of its components look like.', 'start': 24.5, 'duration': 4.3}, {'text': 'The main example, to begin with, will be the classic example:', 'start': 29.24, 'duration': 3.08}, {'text': 'the decomposition of sound frequencies.', 'start': 32.32, 'duration': 2.04}, {'text': 'But after that, I also want to show how this idea extends far beyond sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'and into a lot of seemingly disparate areas of math, and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': "Really, it's crazy how ubiquitous this idea is.", 'start': 44.6, 'duration': 3.52}, {'text': "Let's go!", 'start': 49.12, 'duration': 0.82}, {'text': 'The sound you hear is pure a.', 'start': 50.54, 'duration': 2.16}, {'text': '440 vibrations per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'This means that if you were to measure the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'right next to your headphones, or your speaker, over time, it would oscillate up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around its usual equilibrium, following this shape.', 'start': 63.16, 'duration': 2.94}, {'text': 'doing 440 oscillations every second.', 'start': 66.1, 'duration': 3.4}, {'text': 'A lower note, like a D, has the same structure, with just fewer oscillations per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when both are played at the same time,', 'start': 75.5, 'duration': 5.52}, {'text': 'well, at any point in time that pressure difference is', 'start': 82.16, 'duration': 3.02}, {'text': 'going to be the sum of what it would be for each of those notes individually.', 'start': 85.18, 'duration': 4.1}, {'text': "Which, let's face it, is a complicated thing to think about.", 'start': 89.28, 'duration': 3.68}, {'text': 'At times, the peaks come together,', 'start': 94.08, 'duration': 2.24}, {'text': 'resulting in very high pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other times, they tend to cancel each other out.', 'start': 98.42, 'duration': 2.32}, {'text': 'And overall, what you get is a wave-shaped pressure versus time curve', 'start': 101.38, 'duration': 4.0}, {'text': "that is not a pure sine wave;  it's something more complicated.", 'start': 105.38, 'duration': 3.62}, {'text': 'And when you add more notes, the wave gets more and more complicated.', 'start': 109.0, 'duration': 4.52}, {'text': 'But in fact, it is just a combination of four pure frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems ... unnecessarily complicated, given the small amount of information it contains.', 'start': 118.08, 'duration': 4.32}, {'text': 'A microphone recording any sound', 'start': 122.96, 'duration': 2.02}, {'text': 'simply reads the air pressure at different points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'He "sees" only the final sum.', 'start': 128.42, 'duration': 2.06}, {'text': 'So our essential question is going to be: how can we take', 'start': 130.48, 'duration': 2.92}, {'text': 'a signal like this,', 'start': 133.4, 'duration': 1.38}, {'text': 'and break it down', 'start': 134.78, 'duration': 1.1}, {'text': 'into the pure frequencies that make it up?', 'start': 135.88, 'duration': 2.12}, {'text': 'Rather interesting, no?' ...
# [{'text': "Here's what we're going to build in this video:", 'start': 4.335, 'duration': 3.02}, {'text': 'A certain animated approach to thinking about an', 'start': 7.355, 'duration': 2.55}, {'text': 'extremely important idea in math: The Fourier Transform.', 'start': 9.905, 'duration': 3.1}, {'text': 'My goal for those who are not familiar with it', 'start': 13.205, 'duration': 2.58}, {'text': 'is that the video is simply an', 'start': 15.785, 'duration': 2.83}, {'text': 'introduction  in the subject is.', 'start': 18.62, 'duration': 3.105}, {'text': 'But I think those who know the subject will also enjoy', 'start': 21.725, 'duration': 3.075}, {'text': 'seeing what all the parts of it actually look like.', 'start': 24.8, 'duration': 4.18}, {'text': 'The example at the beginning will be the classic one:', 'start': 28.98, 'duration': 3.12}, {'text': 'extracting frequencies from sounds.', 'start': 32.1, 'duration': 2.36}, {'text': 'But then I will also briefly show', 'start': 34.46, 'duration': 2.16}, {'text': 'how this idea can be expanded beyond Kang and frequencies', 'start': 36.62, 'duration': 3.78}, {'text': 'into many apparently separate areas of mathematics and physics.', 'start': 40.4, 'duration': 4.3}, {'text': "It's crazy how universal this idea is.", 'start': 44.86, 'duration': 3.86}, {'text': "Let's start.", 'start': 48.96, 'duration': 1.02}, {'text': 'This tone is a pure A', 'start': 50.14, 'duration': 3.34}, {'text': '440 Hertz.', 'start': 53.48, 'duration': 1.64}, {'text': 'This means that if you measured the air pressure right next to your speakers', 'start': 55.22, 'duration': 3.36}, {'text': 'as a function of time, it', 'start': 58.74, 'duration': 2.62}, {'text': 'would oscillate around its usual mean value', 'start': 61.4, 'duration': 3.54}, {'text': 'in this wave, at 440 oscillations per second.', 'start': 64.94, 'duration': 4.46}, {'text': 'A lower note has the same structure, only the frequency is lower.', 'start': 69.72, 'duration': 5.12}, {'text': 'And if both are played at the same time, what would', 'start': 75.36, 'duration': 2.915}, {'text': 'the corresponding graph look like?', 'start': 78.275, 'duration': 2.8}, {'text': 'Well, at any point in time the pressure difference', 'start': 82.385, 'duration': 2.94}, {'text': 'is the sum of the pressure differences of the individual notes.', 'start': 85.325, 'duration': 3.995}, {'text': 'To be honest, it is a little tricky to think about.', 'start': 89.6, 'duration': 2.86}, {'text': 'In some places the extreme points coincide and lead to high pressure.', 'start': 94.28, 'duration': 4.14}, {'text': 'In other places the waves cancel each other out.', 'start': 98.695, 'duration': 2.2}, {'text': 'And all in all, you get', 'start': 101.2, 'duration': 2.14}, {'text': 'a wave-like pressure-time diagram that', 'start': 103.34, 'duration': 3.06}, {'text': 'does not show a pure sine function, but is more complicated.', 'start': 106.4, 'duration': 2.76}, {'text': 'And as you add other notes, the wave becomes more and more complicated.', 'start': 109.24, 'duration': 4.3}, {'text': "But it's just a combination of sine functions,", 'start': 113.56, 'duration': 3.02}, {'text': 'so it seems unnecessarily', 'start': 116.58, 'duration': 2.22}, {'text': 'complicated considering the low information content of the individual parts.', 'start': 118.8, 'duration': 3.36}, {'text': 'A microphone that picks up any noise', 'start': 122.16, 'duration': 2.7}, {'text': 'simply measures the air pressure at many different times.', 'start': 124.86, 'duration': 3.1}, {'text': 'It only measures the final total.', 'start': 127.96, 'duration': 2.6}, {'text': 'Our question will be', 'start': 130.56, 'duration': 1.4}, {'text': 'how to break up such a signal into the individual pure frequencies', 'start': 131.98, 'duration': 3.48}, {'text': 'that make it up.', 'start': 135.46, 'duration': 2.64}, {'text': "Pretty interesting, isn't it?", 'start': 138.1, 'duration': 2.0}, {'text': 'When added togeth ...
# [{'text': 'This here is what we will come up with in this video:', 'start': 4.34, 'duration': 2.94}, {'text': 'A specific live approach to thinking about a terribly important mathematical idea:', 'start': 7.28, 'duration': 4.32}, {'text': 'The Fourier transform.', 'start': 11.6, 'duration': 1.36}, {'text': 'Anyone unfamiliar with what this is,', 'start': 13.26, 'duration': 2.38}, {'text': 'my # 1 goal is for this video to be just an introduction to the topic.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who are familiar with it,', 'start': 20.18, 'duration': 2.68}, {'text': 'I think there is something fun', 'start': 22.86, 'duration': 1.64}, {'text': 'and enriching about seeing what all its ingredients look like.', 'start': 24.5, 'duration': 4.3}, {'text': 'The central example, to begin with, will be the classic:', 'start': 29.24, 'duration': 3.08}, {'text': 'The decomposition of audio frequencies.', 'start': 32.32, 'duration': 2.04}, {'text': 'But after that, I also want to show a trace of how this idea expands very well beyond sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'in many seemingly different areas of mathematics, and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': "Really, it's crazy how broad this idea is.", 'start': 44.6, 'duration': 3.52}, {'text': "Let's start. ", 'start': 49.12, 'duration': 0.82}, {'text': 'This sound here is a pure LA.', 'start': 50.54, 'duration': 2.16}, {'text': '440 beats per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'Which means that if you measured the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'right next to your headphones, or your speaker, as a function of time, it would oscillate up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around its normal stability, in this wave', 'start': 63.16, 'duration': 2.94}, {'text': 'creating 440 oscillations every second.', 'start': 66.1, 'duration': 3.4}, {'text': 'A lower pitch, such as PE, has the same structure, with just fewer beats per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when they both play at the same time, how do you think the resulting pressure-time graph looks like?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any point in time, this pressure difference', 'start': 82.16, 'duration': 3.02}, {'text': 'will be the sum of what it would be like for each of these notes separately.', 'start': 85.18, 'duration': 4.1}, {'text': 'Which, of course, made the video an overnight sensation.', 'start': 89.28, 'duration': 3.68}, {'text': 'At some points, the tops', 'start': 94.08, 'duration': 2.24}, {'text': 'fit which leads to very high pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'In other places, they tend to cancel each other out.', 'start': 98.42, 'duration': 2.32}, {'text': 'And finally, what we get is a pressure-time graph with roughly a waveform', 'start': 101.38, 'duration': 4.0}, {'text': ", which is not a pure sine wave, it's something more complicated.", 'start': 105.38, 'duration': 3.62}, {'text': 'And as we add other notes, the wave becomes more and more complex.', 'start': 109.0, 'duration': 4.52}, {'text': 'But now, it is nothing more than a combination of four pure frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'From what it seems ... unnecessarily complicated, given the low amount of information we gave him.', 'start': 118.08, 'duration': 4.32}, {'text': 'A microphone that records any sound', 'start': 122.96, 'duration': 2.02}, {'text': 'simply collects the air pressure at many different times.', 'start': 124.98, 'duration': 3.18}, {'text': 'Just "sees" the final sum.', 'start': 128.42, 'duration': 2.06}, {'text': 'So the central question will be "how can you take', 'start': 130.48, 'duration': 2.92}, {'text': 'such a signal', 'start': 133.4, 'duration': 1.38}, {'text': 'and decompose it', 'start': 134.78, 'duration': 1.1}, {'text': 'into the pure frequencies that compose it.', 'start': 135.88 ...
# [{'text': 'What you see here, is what we are going to build, in this video:', 'start': 4.34, 'duration': 2.94}, {'text': 'a certain approach of animation (animation), to think of a very important idea that comes from mathematics -', 'start': 7.28, 'duration': 4.42}, {'text': 'Fourier Transformation.', 'start': 11.7, 'duration': 1.36}, {'text': 'For anyone unfamiliar with this,', 'start': 13.26, 'duration': 2.38}, {'text': 'my main goal here, is that this video be an introduction to this topic.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who are already familiar with it,', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think there is something fun about it', 'start': 22.86, 'duration': 1.64}, {'text': 'and enriching;  By seeing what all the components of the Transform look like.', 'start': 24.5, 'duration': 4.3}, {'text': 'The main example, for a start, is going to be a classic one:', 'start': 29.24, 'duration': 3.08}, {'text': 'separating the frequencies from the sound (sound).', 'start': 32.32, 'duration': 2.04}, {'text': 'But then, I also want to show you a little glimpse - how this idea extends beyond the matter of sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'and to many areas of mathematics and physics that seem to differ from each other.', 'start': 40.72, 'duration': 3.7}, {'text': "Really, it's crazy how much this idea is in several places at once.", 'start': 44.6, 'duration': 3.52}, {'text': "Let's dive in.", 'start': 49.12, 'duration': 0.82}, {'text': "This sound here is pure 'la' (musical note. In English it is called A).", 'start': 50.54, 'duration': 2.28}, {'text': '440 beats per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'The implication is that if you were to measure the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'near your headphones, or speaker, as a function of time, it would be swinging up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around a constant equilibrium, in this wave.', 'start': 63.16, 'duration': 2.94}, {'text': 'Generates 440 oscillations, every second.', 'start': 66.1, 'duration': 3.4}, {'text': "A musical note with a lower pitch, such as 'Ra' (D in English), has the same structure, but has fewer beats per second.", 'start': 69.5, 'duration': 5.52}, {'text': 'When playing these two notes at the same time, how do you think the graph of air pressure will look as a function of time?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any point in time, this change in pressure', 'start': 82.16, 'duration': 3.02}, {'text': 'would be the sum of what would have happened if we had played each note, individually.', 'start': 85.18, 'duration': 4.1}, {'text': "Which is, let's face it, is kind of something complicated to think about.", 'start': 89.28, 'duration': 3.68}, {'text': 'At certain points, the peaks correspond to each other,', 'start': 94.08, 'duration': 2.24}, {'text': 'which really creates a very high pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other points, they tend to cancel each other out.', 'start': 98.42, 'duration': 2.32}, {'text': 'And in the end, what you get is wavy pressure against the graph of time,', 'start': 101.38, 'duration': 4.0}, {'text': "it's not a pure sinusoidal wave, it's something more complicated.", 'start': 105.38, 'duration': 3.62}, {'text': 'And as you add the other characters, the wave becomes more and more complex.', 'start': 109.0, 'duration': 4.52}, {'text': 'But now, all it is, is a combination of 4 pure frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems unnecessarily complicated, given the small amount of information we put here.', 'start': 118.08, 'duration': 4.32}, {'text': 'A microphone records every sound,', 'start': 122.96, 'duration': 2.02}, {'text': 'it simply picks up the air pressure at a large number of different points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'He only "sees" the final amount.', 'start': 128. ...
# [{'text': 'These things here are what we will be addressing in this video', 'start': 4.34, 'duration': 2.94}, {'text': 'An Animation-Based Approach that Allows Us to Think of a Super-Important Idea of Mathematics:', 'start': 7.28, 'duration': 4.32}, {'text': 'The Fourier Transform.', 'start': 11.6, 'duration': 1.36}, {'text': 'For those unfamiliar with this concept', 'start': 13.26, 'duration': 2.38}, {'text': ', my # 1 goal of the video is just to give you an introduction to the topic.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who are already familiar with this topic,', 'start': 20.18, 'duration': 2.68}, {'text': 'I think there may be something fun', 'start': 22.86, 'duration': 1.64}, {'text': 'and interesting in visually seeing how all of its components are made.', 'start': 24.5, 'duration': 4.3}, {'text': 'The main example, to begin with, will be the typical example:', 'start': 29.24, 'duration': 3.08}, {'text': 'The decomposition of the frequencies of a sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'But after that, I also want to take a look at how this idea extends far beyond sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'and into many seemingly different areas of mathematics, and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': "Really, it's crazy how ubiquitous this idea is.", 'start': 44.6, 'duration': 3.52}, {'text': "Let's take a look. ", 'start': 49.12, 'duration': 0.82}, {'text': 'This sound here is an A.', 'start': 50.54, 'duration': 2.16}, {'text': '440 beats per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'That is, if you were to measure air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'as a function of time, right next to your headphones, or your speaker, it would swing up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around its center, forming this wave.', 'start': 63.16, 'duration': 2.94}, {'text': 'making 440 swings per second.', 'start': 66.1, 'duration': 3.4}, {'text': 'A less high note, like a D, has the same structure, only fewer beats per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when both are played at the same time, what do you think is the resulting graph of pressure versus time?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any given instant, this pressure difference', 'start': 82.16, 'duration': 3.02}, {'text': 'will be the sum of what it would have been for each of those notes taken individually.', 'start': 85.18, 'duration': 4.1}, {'text': "Let's face it, it's a complicated thing to imagine.", 'start': 89.28, 'duration': 3.68}, {'text': 'In some places, the peaks combine,', 'start': 94.08, 'duration': 2.24}, {'text': 'giving a very high pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'In other places, they tend to cancel out.', 'start': 98.42, 'duration': 2.32}, {'text': 'And all in all, what you get is a "rippling" pressure-time graph,', 'start': 101.38, 'duration': 4.0}, {'text': "that's not a pure sine wave;  it is something more complicated.", 'start': 105.38, 'duration': 3.62}, {'text': 'And as you add more notes, the wave gets more and more complicated.', 'start': 109.0, 'duration': 4.52}, {'text': 'But at the moment, it is a combination of four "pure" frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems ... unnecessarily complicated, given the low amount of information entered inside.', 'start': 118.08, 'duration': 4.32}, {'text': 'A microphone that records any sound', 'start': 122.96, 'duration': 2.02}, {'text': 'records the air pressure in many instants of time.', 'start': 124.98, 'duration': 3.18}, {'text': 'But he "sees" only the final sum.', 'start': 128.42, 'duration': 2.06}, {'text': 'So our main question will be how you can take', 'start': 130.48, 'duration': 2.92}, {'text': 'a signal like this,', 'start': 133.4, 'duration': 1.38}, {'text': 'and decompose it', 'start': 134.78, 'duration': 1.1}, {'text': 'into the pure frequencies that  ...
# [{'text': 'What you see now is the result of this video we are going to make today\n.', 'start': 4.34, 'duration': 2.96}, {'text': 'A\nvery important idea of mathematics is approached through a moving image, and', 'start': 7.3, 'duration': 4.36}, {'text': 'the idea is a\nFourier transform.  For those unfamiliar', 'start': 11.66, 'duration': 1.34}, {'text': 'with what a Fourier transform is\n,', 'start': 13.2, 'duration': 2.58}, {'text': 'the main purpose of this video is\nto introduce you to the concept.', 'start': 15.78, 'duration': 4.46}, {'text': 'However,\neven if you are already familiar with', 'start': 20.24, 'duration': 2.56}, {'text': 'Fourier Transform, I think it will be interesting and inspiring to see the elements that make up the Fourier Transform in\n', 'start': 22.8, 'duration': 2.9}, {'text': '\naction.', 'start': 25.7, 'duration': 3.56}, {'text': "\nLet's start the story with a classic example at the center.", 'start': 29.26, 'duration': 2.9}, {'text': 'It is the decomposition of sound into frequencies.', 'start': 32.16, 'duration': 2.38}, {'text': 'But after that, I want to show you a little bit of how this idea extends', 'start': 34.54, 'duration': 2.44}, {'text': 'not only to sound, but also to\nseemingly unrelated', 'start': 36.98, 'duration': 2.7}, {'text': 'fields of mathematics, even physics\n', 'start': 39.68, 'duration': 2.42}, {'text': '.', 'start': 42.1, 'duration': 2.7}, {'text': 'Indeed, this idea is\nridiculously', 'start': 44.8, 'duration': 1.98}, {'text': 'ubiquitous.', 'start': 46.78, 'duration': 1.72}, {'text': "Let's get started.", 'start': 48.965, 'duration': 1.01}, {'text': 'This sound is pure A (A).', 'start': 50.38, 'duration': 2.72}, {'text': 'It rings 440 times per second.', 'start': 53.1, 'duration': 1.94}, {'text': 'What this means is that when you measure\nthe barometric pressure right next to a speaker or headphone', 'start': 55.04, 'duration': 2.5}, {'text': ', it will draw a waveform like this as a function of time, as if the', 'start': 59.84, 'duration': 1.5}, {'text': 'barometric pressure were oscillating up and down in\nequilibrium', 'start': 61.4, 'duration': 3.54}, {'text': '.\nIt vibrates 440 times every second', 'start': 64.945, 'duration': 2.92}, {'text': '.', 'start': 67.865, 'duration': 2.035}, {'text': 'Low notes like D (D)\nhave the same structure.', 'start': 69.9, 'duration': 3.58}, {'text': 'It just beeps less often per second.', 'start': 73.48, 'duration': 2.0}, {'text': 'And if those two notes sounded at the same', 'start': 75.48, 'duration': 2.36}, {'text': 'time, what would the graph of pressure versus time\nlook like?', 'start': 77.84, 'duration': 3.24}, {'text': 'At any point in time, the result is', 'start': 82.3, 'duration': 1.7}, {'text': 'equal to the sum of the values the two notes would have originally each had', 'start': 84.0, 'duration': 2.56}, {'text': '.', 'start': 86.56, 'duration': 3.18}, {'text': "If you think about it, it's pretty", 'start': 89.74, 'duration': 1.235}, {'text': 'complicated.', 'start': 90.98, 'duration': 3.2}, {'text': 'At some point, the\nhigh parts are joined together to create a', 'start': 94.18, 'duration': 2.28}, {'text': 'very high barometric pressure.', 'start': 96.46, 'duration': 2.32}, {'text': 'In some ways,\nthey cancel each other out.', 'start': 98.78, 'duration': 2.56}, {'text': 'Taken together,', 'start': 101.34, 'duration': 1.58}, {'text': 'this graph of barometric pressure versus time is not a', 'start': 102.92, 'duration': 2.6}, {'text': 'pure sine wave\n.', 'start': 105.52, 'duration': 1.66}, {'text': "It's a little more complicated.", 'start': 107.18, 'duration': 2.26}, {'text': 'And if you add more other notes, the', 'start': 109.44, 'duration': 1.92}, {'text': 'waveform gets more and more complex.', 'start': 111.36, 'duration': 2.375}, {'text': 'But when you look into reality,', 'start': 113.74, 'duration': 2.14}, {'text': 'these are\nnothing more than the sum of four pure frequencies.', 'start': 115.88, 'dura ...
# [{'text': 'What we have here is what we are going to cover in this video:', 'start': 4.34, 'duration': 2.94}, {'text': 'A specific animated approach to thinking about an extremely important mathematical idea: the', 'start': 7.28, 'duration': 4.32}, {'text': 'Fourier transform', 'start': 11.6, 'duration': 1.36}, {'text': 'for anyone unfamiliar with.', 'start': 13.26, 'duration': 2.38}, {'text': 'My first goal in this video is to express  This is an introduction.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who were already familiar with it,', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think it is something fun', 'start': 22.86, 'duration': 1.64}, {'text': 'and enriching to see what all its components look like.', 'start': 24.5, 'duration': 4.3}, {'text': 'A central example to begin with would be the classic:', 'start': 29.24, 'duration': 3.08}, {'text': 'split frequencies of sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'But then, I also really want a glimpse into how the idea goes far beyond sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'and into many unknown areas of mathematics and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': "It's really crazy how this idea is everywhere.", 'start': 44.6, 'duration': 3.52}, {'text': "Let's dive in.", 'start': 49.12, 'duration': 0.82}, {'text': 'The sound you hear here is', 'start': 50.54, 'duration': 2.16}, {'text': 'a pure sound of 440 beats per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'This means that, if you could measure the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'right next to your headphones, or your speakers, as a function of time, it would fluctuate and go up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'in the balanced part of the', 'start': 63.16, 'duration': 2.94}, {'text': '440 wave oscillation per  Makes', 'start': 66.1, 'duration': 3.4}, {'text': 'a second A lower note, like a D note, has the same structure, only having a lower heart rate per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when they both play together, what do you think the pressure from the time graph looks like?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any given moment, this pressure difference', 'start': 82.16, 'duration': 3.02}, {'text': 'for each of these notes accumulates separately.', 'start': 85.18, 'duration': 4.1}, {'text': "Which, let's face it, is a little tricky to think about.", 'start': 89.28, 'duration': 3.68}, {'text': 'In some places, the peaks overlap,', 'start': 94.08, 'duration': 2.24}, {'text': 'resulting in a high pressure.', 'start': 96.32, 'duration': 2.1}, {'text': 'Elsewhere, they neutralize each other.', 'start': 98.42, 'duration': 2.32}, {'text': 'And finally, you get the pressure of the waves in front of the time graph,', 'start': 101.38, 'duration': 4.0}, {'text': 'this is not a pure sine wave, something more complicated.', 'start': 105.38, 'duration': 3.62}, {'text': 'Also, if you add other notes, the wave becomes more complex.', 'start': 109.0, 'duration': 4.52}, {'text': 'But for now, all of this is a combination of four pure frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems ... given the small amount of information it contains, there is no need for complexity.', 'start': 118.08, 'duration': 4.32}, {'text': 'A recording microphone', 'start': 122.96, 'duration': 2.02}, {'text': 'only picks up air pressure at different points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'This results in the final sum,', 'start': 128.42, 'duration': 2.06}, {'text': 'so our main question will be how', 'start': 130.48, 'duration': 2.92}, {'text': 'a signal like this', 'start': 133.4, 'duration': 1.38}, {'text': 'can be decomposed', 'start': 134.78, 'duration': 1.1}, {'text': 'into the pure frequencies that make it up.', 'start': 135.88, 'duration': 2.12}, {'text': 'Very interesting, right?', 'start': 138.62, 'duration': 1. ...
# ...
# [{'text': 'This here is what we are going to build in this video:', 'start': 4.34, 'duration': 2.94}, {'text': 'An animated approach to understanding a super important mathematical idea:', 'start': 7.28, 'duration': 4.32}, {'text': 'The Fourier Transform', 'start': 11.6, 'duration': 1.36}, {'text': 'For those who are not familiar with what', 'start': 13.26, 'duration': 2.38}, {'text': 'my # 1 goal is that this video is an introduction to said  topic. ', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who are already familiar,', 'start': 20.18, 'duration': 2.68}, {'text': 'I think you will find it quite fun', 'start': 22.86, 'duration': 1.64}, {'text': 'and enriching to understand how all of its components can be viewed.', 'start': 24.5, 'duration': 4.3}, {'text': 'The central example, to begin with, will be the classic one:', 'start': 29.24, 'duration': 3.08}, {'text': 'Decompose the frequencies of the sound.', 'start': 32.32, 'duration': 2.04}, {'text': 'After that, I really want to illustrate how this idea extends beyond sound and frequency,', 'start': 34.36, 'duration': 6.36}, {'text': 'into many seemingly disparate areas of mathematics, and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': 'It really is pretty crazy how ubiquitous this idea is.', 'start': 44.6, 'duration': 3.52}, {'text': "Let's dive in.", 'start': 49.12, 'duration': 0.82}, {'text': 'This sound is a pure "A".', 'start': 50.54, 'duration': 2.16}, {'text': '440 vibrations per second.', 'start': 53.02, 'duration': 1.96}, {'text': 'This means that if you measured the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'next to your headphones or speakers, as a function of time, the air pressure would oscillate up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around its usual equilibrium, in this wave.', 'start': 63.16, 'duration': 2.94}, {'text': 'making 440 oscillations every second', 'start': 66.1, 'duration': 3.4}, {'text': 'A lower note, like a "D", has the same structure, only less vibrations per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when both notes are played at the same time, what do you think the resulting graph of pressure vs.  weather? ', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at each instant of time, said pressure difference', 'start': 82.16, 'duration': 3.02}, {'text': 'will be the sum of those notes separately.', 'start': 85.18, 'duration': 4.1}, {'text': "Which, let's face it, is a bit complicated to think about.", 'start': 89.28, 'duration': 3.68}, {'text': 'At some points, the tops coincide with each other,', 'start': 94.08, 'duration': 2.24}, {'text': 'resulting in a fairly high pressure difference.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other points, they tend to cancel.', 'start': 98.42, 'duration': 2.32}, {'text': 'And so what you get is a wave graph of pressure vs.  time,', 'start': 101.38, 'duration': 4.0}, {'text': 'Which is not purely like the breast;  it is somewhat more complicated.', 'start': 105.38, 'duration': 3.62}, {'text': 'And as we add more notes, the resulting wave is more complicated.', 'start': 109.0, 'duration': 4.52}, {'text': 'For now, all of it is a combination of four pure frequencies.', 'start': 113.68, 'duration': 4.4}, {'text': 'Which seems ... unnecessarily complicated, given the little information put into it.', 'start': 118.08, 'duration': 4.32}, {'text': 'When recording any sound, a microphone', 'start': 122.96, 'duration': 2.02}, {'text': 'simply takes the air pressure at different points of time: it', 'start': 124.98, 'duration': 3.18}, {'text': 'only records the final sum.', 'start': 128.42, 'duration': 2.06}, {'text': 'Thus, our central question will be how we can take', 'start': 130.48, 'duration': 2.92}, {'text': 'a signal like this,', 'start': 133.4, 'duration': 1.38}, {'text': 'and break it down', 'start': 134.78, 'duration': 1.1}, {'text': 'into the pure frequencies that formed it.', 'start': 135.88, 'duration': 2.1 ...
# [{'text': "Here's what we're going to build, this video:", 'start': 4.34, 'duration': 2.94}, {'text': 'Some kind of animated method to think about a super important idea from math', 'start': 7.28, 'duration': 4.32}, {'text': 'Fourier transform', 'start': 11.6, 'duration': 1.36}, {'text': 'For anyone unfamiliar with that', 'start': 13.26, 'duration': 2.38}, {'text': 'numerical objective  1 here is just for an introduction to that topic.', 'start': 15.64, 'duration': 4.54}, {'text': 'But even for those of you who are already familiar with it,', 'start': 20.18, 'duration': 2.68}, {'text': 'I still think there is something interesting', 'start': 22.86, 'duration': 1.64}, {'text': 'and enriching about seeing what all its components look like.', 'start': 24.5, 'duration': 4.3}, {'text': 'The central example, to begin with, would be a good example:', 'start': 29.24, 'duration': 3.08}, {'text': 'Analysis of frequencies from audio.', 'start': 32.32, 'duration': 2.04}, {'text': 'But then, I also really wanted to show the idea of this idea going beyond sounds and frequencies like that.  really,', 'start': 34.36, 'duration': 6.36}, {'text': 'and many different areas of math, and even physics.', 'start': 40.72, 'duration': 3.7}, {'text': 'Really, how crazy it is is this popular idea.', 'start': 44.6, 'duration': 3.52}, {'text': "Let's dive into", 'start': 49.12, 'duration': 0.82}, {'text': 'this Sound right here is pure A.', 'start': 50.54, 'duration': 2.16}, {'text': '440 beats per second', 'start': 53.02, 'duration': 1.96}, {'text': 'That means, if you measure the air pressure', 'start': 54.98, 'duration': 2.52}, {'text': 'right next to your headphones, or your speakers, as a function of time, it will oscillate up and down', 'start': 57.5, 'duration': 5.66}, {'text': 'around the equilibrium through  its normal, in this wave', 'start': 63.16, 'duration': 2.94}, {'text': 'produces 440 oscillations per second.', 'start': 66.1, 'duration': 3.4}, {'text': 'A lower note, like the letter D, has the same structure, only a few beats per second.', 'start': 69.5, 'duration': 5.52}, {'text': 'And when both are played at the same time, what do you think the result is compared to the time graph?', 'start': 75.5, 'duration': 5.52}, {'text': 'Well, at any given time, this pressure difference', 'start': 82.16, 'duration': 3.02}, {'text': 'will be the sum of each of those notes.', 'start': 85.18, 'duration': 4.1}, {'text': "Come on, let's face it, it's a complicated thing to think about.", 'start': 89.28, 'duration': 3.68}, {'text': 'At some point the peaks fit together,', 'start': 94.08, 'duration': 2.24}, {'text': 'resulting in really high pressures.', 'start': 96.32, 'duration': 2.1}, {'text': 'At other points, they tend to cancel.', 'start': 98.42, 'duration': 2.32}, {'text': 'And all in all, what you get is pressure wave-ish versus time graph,', 'start': 101.38, 'duration': 4.0}, {'text': "which is not a pure sine wave;  it's something more complicated.", 'start': 105.38, 'duration': 3.62}, {'text': 'And as you add in other notes, the waves get more and more complex.', 'start': 109.0, 'duration': 4.52}, {'text': "But right now, it's all a combination of four pure frequencies.", 'start': 113.68, 'duration': 4.4}, {'text': 'So it seems... unnecessarily complicated, given the low amount of information put into it.', 'start': 118.08, 'duration': 4.32}, {'text': 'Microphones that record any sound', 'start': 122.96, 'duration': 2.02}, {'text': 'simply pick up the air pressure at various points in time.', 'start': 124.98, 'duration': 3.18}, {'text': 'It only "sees" the final amount.', 'start': 128.42, 'duration': 2.06}, {'text': 'So our central question will be how can you take', 'start': 130.48, 'duration': 2.92}, {'text': 'a signal like this,', 'start': 133.4, 'duration': 1.38}, {'text': 'and decompose it', 'start': 134.78, 'duration': 1.1}, {'text': 'into the pure frequencies that make it up.', 'start': 135.88, 'duration': 2.12}, {'text': "Pretty interes ...
# [{'text': '[Music]', 'start': 0.0, 'duration': 3.139}, {'text': 'this right here', 'start': 4.64, 'duration': 2.159}, {'text': "is what we're going to build to this", 'start': 5.44, 'duration': 3.6}, {'text': 'video a certain animated approach to', 'start': 6.799, 'duration': 4.321}, {'text': 'thinking about a super important idea', 'start': 9.04, 'duration': 4.4}, {'text': 'from math the fourier transform', 'start': 11.12, 'duration': 4.639}, {'text': 'for anyone unfamiliar with what that is', 'start': 13.44, 'duration': 4.16}, {'text': 'my number one goal here is just for the', 'start': 15.759, 'duration': 2.721}, {'text': 'video to be an', 'start': 17.6, 'duration': 3.2}, {'text': 'introduction to that topic but even for', 'start': 18.48, 'duration': 3.84}, {'text': 'those of you who are already familiar', 'start': 20.8, 'duration': 2.08}, {'text': 'with it', 'start': 22.32, 'duration': 2.24}, {'text': "i still think that there's something fun", 'start': 22.88, 'duration': 3.76}, {'text': 'and enriching about seeing what all of', 'start': 24.56, 'duration': 3.12}, {'text': 'its components', 'start': 26.64, 'duration': 3.6}, {'text': 'actually look like the central example', 'start': 27.68, 'duration': 4.719}, {'text': 'to start is going to be the classic one', 'start': 30.24, 'duration': 4.479}, {'text': 'decomposing frequencies from sound but', 'start': 32.399, 'duration': 3.84}, {'text': 'after that i also really want to show a', 'start': 34.719, 'duration': 2.241}, {'text': 'glimpse of', 'start': 36.239, 'duration': 3.601}, {'text': 'how this idea extends well beyond sound', 'start': 36.96, 'duration': 3.759}, {'text': 'and frequency', 'start': 39.84, 'duration': 3.12}, {'text': 'into many seemingly disparate areas of', 'start': 40.719, 'duration': 4.0}, {'text': 'math and even physics', 'start': 42.96, 'duration': 4.16}, {'text': 'really it is crazy just how ubiquitous', 'start': 44.719, 'duration': 4.32}, {'text': 'this idea is', 'start': 47.12, 'duration': 4.72}, {'text': "let's dive in this sound right here is a", 'start': 49.039, 'duration': 3.36}, {'text': 'pure', 'start': 51.84, 'duration': 3.68}, {'text': 'a 440 beats per second meaning', 'start': 52.399, 'duration': 5.121}, {'text': 'if you were to measure the air pressure', 'start': 55.52, 'duration': 3.679}, {'text': 'right next to your headphones or your', 'start': 57.52, 'duration': 2.4}, {'text': 'speaker', 'start': 59.199, 'duration': 3.2}, {'text': 'as a function of time it would oscillate', 'start': 59.92, 'duration': 3.36}, {'text': 'up and down', 'start': 62.399, 'duration': 3.12}, {'text': 'around its usual equilibrium in this', 'start': 63.28, 'duration': 3.36}, {'text': 'wave making', 'start': 65.519, 'duration': 4.241}, {'text': '440 oscillations each second', 'start': 66.64, 'duration': 5.6}, {'text': 'a lower pitch note like a d has the same', 'start': 69.76, 'duration': 3.12}, {'text': 'structure', 'start': 72.24, 'duration': 3.68}, {'text': 'just fewer beats per second and when', 'start': 72.88, 'duration': 4.72}, {'text': 'both of them are played at once', 'start': 75.92, 'duration': 3.28}, {'text': 'what do you think the resulting pressure', 'start': 77.6, 'duration': 4.64}, {'text': 'versus time graph looks like', 'start': 79.2, 'duration': 5.44}, {'text': 'well at any point in time this pressure', 'start': 82.24, 'duration': 4.32}, {'text': 'difference is going to be the sum', 'start': 84.64, 'duration': 3.519}, {'text': 'of what it would be for each of those', 'start': 86.56, 'duration': 3.199}, {'text': 'notes individually', 'start': 88.159, 'duration': 3.201}, {'text': "which let's face it is kind of a", 'start': 89.759, 'duration': 4.4}, {'text': 'complicated thing to think about', 'start': 91.36, 'duration': 4.48}, {'text': 'at some points the peaks match up with', 'start': 94.159, 'duration': 3.6}, {'text': 'each other resulting in a really high', 'start': 95.84, 'duration': 2.959}, {'text': 'pressure', 'start': 97.759, 'duration': 3. ...
