# %% [markdown]
# <a href="https://colab.research.google.com/github/remre/StriveSchool-ai/blob/main/m6CV/d8/sol/Corners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### Corners

# %%
image = cv2.imread('chess.jpg')
plt.imshow(image);

# %%
# We will work with the image above
# Convert it to grayscale


# Detect the corners using the cornerHarris


# Display the image with the detected corners

# %%
img = cv2.imread('chess.jpg')

# Convert img to grayscale


# Detect the corners using goodFeaturesToTrack


# Draw the corners on top of img and show it on screen (make sure the corners are visible!)

# %%
waldo = cv2.imread('waldo.jpg')

# %%
wando1 = cv2.imread('/content/WandoScene.jpg')

# %%
copyl = wando1.copy()
gray_scene = cv2.cvtColor(copyl, cv2.COLOR_BGR2GRAY)
gray_wando =cv2.cvtColor(waldo, cv2.COLOR_BGR2GRAY)
results = cv2.matchTemplate(gray_scene,gray_wando,cv2.TM_CCOEFF)
#cv2.normalize(results,results)

# %%
#results

# %%
minVal, maxVal, minLoc,maxLoc = cv2.minMaxLoc(results)

# %%
p1 = maxLoc
p2 = (p1[0]+50,p1[1]+50)
cv2_imshow(cv2.rectangle(copyl,p1,p2,(0,255,0),2))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F122B787ED0>

# %%
sudoku = cv2.imread('sudoku.png')
sudoku = cv2.cvtColor(sudoku, cv2.COLOR_BGR2GRAY)

# %%
#corners
imagee = image.copy()
chess_ = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

chess_g = chess_.copy()

sudoku1 = sudoku.copy()

ret, thresh = cv2.threshold(sudoku1,199,255,cv2.THRESH_BINARY)
corners = cv2.goodFeaturesToTrack(thresh,40,0.1,40 )
type(corners)
for  corner in corners: #coordinates
 x, y =  corner[0]
 x = int(x)
 y = int(y)
 p1 = (x-10,y-10)
 p2 = (x+10,y+10)
 cv2.rectangle(thresh,p1,p2,(0,250,250),cv2.FILLED)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=375x375 at 0x7F1225CB2B10>

# %%
cv2.Sobel(sudoku1, )
# Out:
# [[76. 75.]]
# [[380.  75.]]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow

# %%
people1 = cv2.imread('people1.jpg')
people2 = cv2.imread('people2.jpg')
people1g = cv2.cvtColor(people1, cv2.COLOR_BGR2GRAY)
people2g = cv2.cvtColor(people2, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(people2)
# Out:
# <PIL.Image.Image image mode=RGB size=370x208 at 0x7F1225CDF450>

# %%
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
people2c = people2.copy()
faces = face_classifier.detectMultiScale(people2c,minNeighbors = 5)
for (x,y,w,h) in faces:
  p1 = (x,y)
  p2 = (x+w, y+h)
  cv2.rectangle(people2c,p1,p2,(0,255,0),3)
cv2_imshow(people2c)
# Out:
# <PIL.Image.Image image mode=RGB size=370x208 at 0x7F64CBAEA090>

# %%
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# array([[  5,   6,  30,  30],
#        [168,  19,  58,  58],
#        [ 46,  34,  50,  50],
#        [270,  39,  51,  51]], dtype=int32)

# %%
img = cv2.imread("people2.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_classifier.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_classifier.detectMultiScale(roi_color)
for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=370x208 at 0x7F64C69E0C50>

# %%
people1c = people1g.copy()
people2c = people2g.copy()

# make it like first detect faces than add loop to eyes for detection bcz it is hard to detect from whole image

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')


faces = face_classifier.detectMultiScale(people2c,1.1,minNeighbors=5)

for (x,y,w,h) in faces:

  p1 = (x,y)
  p2 = (x+w, y+h)
  cv2.rectangle(people2c,p1,p2,(0,255,0),3)
  img = people2c[p1[1]:p2[1],p1[0]:p2[0]]
  img = cv2.resize(img,(100,100),interpolation = cv2.INTER_LANCZOS4)
  #while type(img) != None:
  eyes = eye_classifier.detectMultiScale(img,minNeighbors=15)
  for (xe,ye,we,he) in eyes:
    p1e = (xe,ye)
    p2e = (xe+we, ye+he)
    cv2.rectangle(img,p1e,p2e,(0,0,255),3)
    
    #cv2_imshow(people2)

    plt.figure(figsize=(9,9))

    plt.imshow(img)

# %%
 p1
# Out:
# (270, 39)

# %%
p2
# Out:
# (321, 90)

# %%
import cv2
import numpy as np 


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')

cap = cv2.VideoCapture(0)

while (True):
    ret, img = cap.read()

    gray_frame = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces  = face_classifier.detectMultiScale(gray_frame, 1.3, 5)
    for (x,y,w,h) in faces:
        p1 = (x,y)
        p2 = (x+w, y+h)
        cv2.rectangle(img,p1,p2,(0,255,0),3)
        roi_gray = gray_frame[p1[1]:p2[1],p1[0]:p2[0]]
        roi_color = img[p1[1]:p2[1],p1[0]:p2[0]]
        eyes = eye_classifier.detectMultiScale(roi_gray,minNeighbors=5)
        for (xe,ye,we,he) in eyes:
           p1e = (xe,ye)
           p2e = (xe+we, ye+he)
           cv2.rectangle(img,p1e,p2e,(0,0,255),3)


    cv2.imshow('bu mudur?', img)

    key = 0 
    if key == ord('q'):
        break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-40-070b77d6ff93> in <module>()
#      11     ret, img = cap.read()
#      12
# ---> 13     gray_frame = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#      14     faces  = face_classifier.detectMultiScale(gray_frame, 1.3, 5)
#      15     for (x,y,w,h) in faces:
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
type(img)
# Out:
# NoneType
