# %% [markdown]
# <a href="https://colab.research.google.com/github/remre/StriveSchool-ai/blob/main/week3/d3/Calculus_Strive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CALCULUS BEGINNER**
#
# > Girintili blok

# %% [markdown]
# ##Exponents

# %% [markdown]
# The exponent of a number says how many times to use the number in a multiplication.
#
# *Example*:
#
# if we need to calculate a^3 we need to multiply a with 3 times
# a^3 = a x a x a

# %% [markdown]
# !!!!!WATCH OUT!!!!
#
# (a^2)^3 != (a^2)x(a^3)

# %%
""" How to execute exponents in python"""
#The function will take the nth power of x 
def expo(x,n):
  #use "**" operator when then specify the power of exponent!! 
  return x**n
expo(2,4)
# Out:
# 16

# %%
#or you can use "pow()" function to execute exponents, see how it is done


pow(4,3)      # 4 is stands for base value and 3 is stands for power of exponent
# Out:
# 64.0

# %% [markdown]
# Do not use "^" instead of "**" in Python, won`t get the right answer!!

# %% [markdown]
# ###Negative and Fractional Exponents
#
# We are multiplying when we have a positive exponent value.  You can imagine "Negative" Exponents like the opposite of multiplying it. Then divide it!
#
#
# !!During the coding be careful with using **paranthesis** and consider **Order of operations**  always¡¡
#
#
#
# *Example:*
# 2^(-3) = 1/(2^3)
#
# A fractional exponent is a technique for expressing powers and roots together. The general form of a fractional exponent is:
#
# b n/m = (m √b) n = m √ (b n), let us define some the terms of this expression.
#
# *Example:*

# %%
#lets find out the value of 1/2 power of 2
pow(4,(1/4))
# Out:
# 1.4142135623730951

# %%
y = Symbol("y")
y**2/3
# Out:
# y**2/3

# %%
sqrt(4)
# Out:
# 2

# %%
x = 2**(2/3)
y = (2**2)
y = y **(1/3)
x == y  #Imagine like first take the power of 2 of 2 then take pwer of 1/3
# Out:
# True

# %% [markdown]
# ##Limits

# %% [markdown]
# Limits describe how a function behaves near a point, instead of at that point. This simple yet powerful idea is the basis of all of calculus.
#  Check out the notation!!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's look how to apply it on Python
#  Consider this:
#
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###How to make it in Python

# %% [markdown]
# SymPy can compute symbolic limits with the limit function.
# The syntax to compute is
#
#  **limit(f(x), x, x0)**.
#
# f(x), x, x0 is noted above how ever "dir" is important it will show where to close this limit in "+" or "-" direction
#
#  *Example:*

# %%
from sympy import * #Use Sympy library to execute limit function
"""
from numpy import *
x = array([1,2,3,4,5])
type(x) #try it u will get it
"""

limit(1/x,x,oo,dir = "+")# oo or -oo stands for infinite and minus infinite
# Out:
# 0

# %% [markdown]
# ##Derivatives

# %% [markdown]
# The whole idea of differentiation is so central to calculus that
# there is a special notation for it.
# First, the Greek letter δ, i.e. ‘delta’, denotes not a number but
# the phrase ‘increase in . . .’. So, for example, if x were to increase
# from 1 to 1.01, then δx would be 0.01.
# In this way, then, δx and δy denote the small increases in
# x and y that occur as we move along some curve from the
# point P to a nearby point Q.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, as we have seen, the whole process of differentiation
# involves finding the limit of δy/δx as δx → 0, i.e. as Q moves closer
# and closer to P.
# And we now denote this limit by the special symbol dy/dx.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Example:*
#
# Derivative of f(x) = x**2
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now offer a second example, if only to show the dy/dx
# notation in action.
# Suppose, then, that y = 1/x.
# Notably, as x increases, y decreases in this case,  so we might reasonably expect a negative slope,
# and therefore a negative value of dy/dx.
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Partial Derivatives

# %% [markdown]
# When it comes to "Partial deriative" main difference is the number of variables we have.
#
#
# Recall that given a function of one variable,
# f
# (
# x
# )
# , the derivative,
# f
# ′
# (
# x
# )
# , represents the rate of change of the function as
# x
#  changes. This is an important interpretation of derivatives and we are not going to want to lose it with functions of more than one variable. The problem with functions of more than one variable is that there is more than one variable. In other words, what do we do if we only want one of the variables to change, or if we want more than one of them to change? In fact, if we’re going to allow more than one of the variables to change there are then going to be an infinite amount of ways for them to change. For instance, one variable could be changing faster than the other variable(s) in the function. Notice as well that it will be completely possible for the function to be changing differently depending on how we allow one or more of the variables to change.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
z = 2*x**3*(y**3)
diff(z,y)
# Out:
# 6*x**3*y**2

# %% [markdown]
# ###How to make it in Python

# %%
"""To take derivatives, use the "diff" function"""
y = Symbol("y")
x = Symbol("x")

# %%
diff(cos(x),x) #derivative of cos(x) with respect to x
# Out:
# -sin(x)

# %%
diff(y,x,2)
diff(y,x,x)# take the derivative of "y" with respect to "x" power of 2 this is how to do it in 2 ways
# Out:
# 12*x**2

# %%
z = (x**3)+(y**2)+2*y*x
diff(z,x,y) #take the partial derivative of y with respect to "z"
# Out:
# 2

# %%
integrate(cos(x),x)
# Out:
# sin(x)

# %% [markdown]
# ##Gradient Descent

# %% [markdown]
# Gradient descent is a first-order iterative optimization algorithm for finding the minimum of a function.
#
# It is crucial when it comes to ml models to aim minimum errors.

# %% [markdown]
# Two basic steps of Gradient Descent
#
# 1.   Compute the slope (gradient) that is first order derivative of the function at the current point
#
# 2.  Move in the opposite direction of the slope increase from the current point by the computed amount
#
#
# Want to go further visit **References and Further Readings**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Integrals

# %% [markdown]
#  The most common meaning is the the fundamenetal object of calculus corresponding to summing infinitesimal pieces to find the content of a continuous region.

# %% [markdown]
# ####How to Make it in Python

# %% [markdown]
#  From sympy library;
#
#   integrate(function or equaiton,(integration variable, lower limit, upper limit))

# %% [markdown]
# >>You can create unevaluated integral using Integral object, which can be evaluated by calling doit() method.

# %%
expr = Integral(log(x)**2, x) 
expr
# Out:
# Integral(log(x)**2, x)

# %%
expr.doit()
# Out:
# x*log(x)**2 - 2*x*log(x) + 2*x

# %% [markdown]
# *Example:*

# %%
integrate(x**2,(x,10,20))
# Out:
# 7000/3

# %%
expr=-x**2
integrate(expr,(x,0,10) )
# Out:
# -1000/3

# %% [markdown]
# ##**Calculus Exercises Strive**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We will use the "SymPy" which is a Python library for symbolic mathematics.
#
# Also "scipy" could be used [scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.misc.derivative.html)

# %% [markdown]
# ###Polynomial Derivatives

# %%
#Importing libraries 
from sympy import * #why doing like that

"""
from numpy import *
x = array([1,2,3,4,5])
type(x) #try it u will get it
"""
# Out:
# '\nfrom numpy import *\nx = array([1,2,3,4,5])\ntype(x) #try it u will get it\n'

# %%
x = Symbol("x")#Define your variables as symbols bcz now work with integers.

# %%
y = (x**2)+2*x+1 #the equation of function f(x) = (x^2)+2*x+1
yprime  = diff(y) # first derivative of y called "yprime" and execute "diff" function to see it!
yprime
# Out:
# 2*x + 2

# %%
y = diff(((x**2)/2)-5*x+1)
y
# Out:
# x - 5

# %%
y  = diff(x**(0.5))
y
# Out:
# 0.5*x**(-0.5)

# %%
y = ((((6*(x**6))/4)*((-9*(x**5))/7))+2*x**2)
y_prime = diff(y)
y_prime
# Out:
# -297*x**10/14 + 4*x

# %%
y = (((x**3)/2)-x**2+1+2*x**2)
y = diff(y)
y
# Out:
# 3*x**2/2 + 2*x

# %%
y = (x**(-1/2))/2
y = diff(y)
y
# Out:
# -0.25*x**(-1.5)

# %%
y = Symbol("y")
x = Symbol("x")
x = ((x**-1)/2)*y**5
x = diff(x,y)
x
# Out:
# 5*y**4/(2*x)

# %% [markdown]
# ###Trigonometry

# %%
x = Symbol("x")
diff(cos(x),x)
# Out:
# -sin(x)

# %%
diff(sin(x),x)
# Out:
# cos(x)

# %%
diff(cos(x**2),x)
# Out:
# -2*x*sin(x**2)

# %%
diff(sin(x**(1/2)),x)
# Out:
# 0.5*x**(-0.5)*cos(x**0.5)

# %% [markdown]
# ###Logarithms

# %% [markdown]
# We should use math library to study on Logarithms too,

# %%
from math import * # this is how we called it
import sympy as sp#dont run it if it is not necessary

# %%
diff(log(x)) #base is "e" so log(x) = lnx in this situation
# Out:
# 1/x

# %%
y =log(x)-log(-x)
sp.diff(y)
# Out:
# 0

# %%
y = log(x)**2
diff(y)
# Out:
# 2*log(x)/x

# %%
y = log(x**2 + 1)
diff(y)
# Out:
# 2*x/(x**2 + 1)

# %% [markdown]
# ##**Calculus Exercises Strive Vol2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Polynomial Derivatives

# %%
from sympy import *
x = Symbol("x")
y = Symbol("y")
diff(x**2+y**2,x)
# Out:
# 2*x

# %%
diff(x**2+y**2,y)
# Out:
# 2*y

# %%
diff(x**2*y**2,y)
# Out:
# 2*x**2*y

# %%
diff(x**2/y**2,x)
# Out:
# 2*x/y**2

# %%
z = (x**2+2*x)/(3*x+y**3)
diff(z,y)
# Out:
# -3*y**2*(x**2 + 2*x)/(3*x + y**3)**2

# %% [markdown]
# ###Trigonometry

# %%
diff(cos(x*y),y)
# Out:
# -x*sin(x*y)

# %%
diff(sin(x*y),y)
# Out:
# x*cos(x*y)

# %%
diff(cos(x**2+4*y),y)
# Out:
# -4*sin(x**2 + 4*y)

# %%
diff(sin(sqrt(x/y)),x)
# Out:
# sqrt(x/y)*cos(sqrt(x/y))/(2*x)

# %%
diff(sin((x**1/2)/(y**1/2)),x)
# Out:
# cos(x/y)/y

# %% [markdown]
# ###Logarithms

# %%
diff(y*log(x),y)
# Out:
# log(x)

# %%
diff(log(x)-x*log(-y),x)
# Out:
# -log(-y) + 1/x

# %%
diff(log(x)/y,y)
# Out:
# -log(x)/y**2

# %%
diff(y**2-log(x**2*y+1),y)
# Out:
# -x**2/(x**2*y + 1) + 2*y

# %%
diff(log(x**2*y+1),y)
# Out:
# x**2/(x**2*y + 1)

# %% [markdown]
# ##References and Further Readings

# %% [markdown]
# >[Khan Academy](https://www.khanacademy.org/math/ap-calculus-ab/ab-limits-new/ab-1-2/a/limits-intro)
#
# >[Sympy](https://docs.sympy.org/latest/tutorial/calculus.html)
#
# >[WolframAlpha](https://www.wolframalpha.com/)
#
#
# >[Stochastic vs Batch Gradient Descents](https://medium.com/@divakar_239/stochastic-vs-batch-gradient-descent-8820568eada1)
#
# >[Lamar Edu](https://tutorial.math.lamar.edu/classes/calciii/partialderivatives.aspx)
#
# >[Joy it!](https://www.youtube.com/watch?v=oVcQTECY_ZQ&ab_channel=thanhtuan2703)
